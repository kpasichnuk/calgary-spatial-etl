# %% [markdown]
# # Project 1 Module 1 Test: Environment and PostGIS
#
# Complete this test after the [practice notebook](../practice/project1_module_1_environment_postgis_practice.ipynb). Use the [reference](../reference/project1_module_1_environment_postgis_reference.md) only after your first attempt.
#
# ## Rules and Scoring
#
# - Use the `calgary-etl` kernel.
# - This test is read-only: it does not install packages, expose secrets, control containers, or write to PostGIS.
# - The test is worth **25 points**: 10 written and 15 executable.
# - A score of **20/25 (80%)** is ready to continue.
#
# ## Written Retrieval: 10 points
#
# 1. Distinguish the project root, working directory, interpreter, and Conda environment.
# 2. Explain installed dependencies versus dependencies declared in `environment.yml`.
# 3. Distinguish a Docker image, container, volume, and port mapping.
# 4. Explain PostgreSQL versus PostGIS and host port `5433` versus container port `5432`.
# 5. Describe a safe diagnostic order for a database connection failure without revealing credentials.

# %%
scores = {}
written_answers = {str(number): "" for number in range(1, 6)}
written_points = {str(number): 0 for number in range(1, 6)}


def record_written_scores() -> None:
    for question, points in written_points.items():
        if not 0 <= points <= 2:
            raise ValueError(f"Written question {question} must be scored from 0 to 2.")
        scores[f"written_{question}"] = (points, 2)
    print("Written scores recorded. Award 2 only for a correct explanation in your own words.")


def run_check(name: str, check_function, possible: int = 3) -> None:
    try:
        check_function()
    except Exception as error:
        scores[name] = (0, possible)
        print(f"NOT YET: {name} - {type(error).__name__}: {error}")
    else:
        scores[name] = (possible, possible)
        print(f"PASS: {name} - {possible}/{possible}")


record_written_scores()

# %%
from pathlib import Path
from urllib.parse import urlparse
import sys

ROOT_MARKERS = ("environment.yml", "docker-compose.yml", "src")

# Exercise 1: Search the start path and its parents for every root marker.
def find_project_root(start: Path) -> Path:
    raise NotImplementedError("TODO")

# Exercise 2: Report interpreter filename and environment directory without guessing.
def interpreter_context(executable: str) -> tuple[str, str]:
    return "TODO", "TODO"

# Exercise 3: Parse a fake URL and return only scheme, host, port, and database.
def safe_connection_facts(url: str) -> tuple[str, str, int, str]:
    return "TODO", "TODO", 0, "TODO"

# Exercise 4: Convert HOST:CONTAINER text into integer ports.
def parse_port_mapping(mapping: str) -> tuple[int, int]:
    return 0, 0

# Exercise 5: Map each check to the narrow fact it proves.
verification_evidence = {
    "docker compose ps": "TODO",
    "database connection": "TODO",
    "SELECT PostGIS_Version()": "TODO",
}


def check_root():
    root = find_project_root(Path.cwd())
    assert all((root / marker).exists() for marker in ROOT_MARKERS)


def check_interpreter():
    name, environment = interpreter_context(sys.executable)
    assert name.startswith("python")
    assert environment == Path(sys.executable).parent.parent.name


def check_url():
    fake = "postgresql+psycopg2://student:secret@localhost:5433/calgary_gis"
    assert safe_connection_facts(fake) == ("postgresql+psycopg2", "localhost", 5433, "calgary_gis")


def check_ports():
    assert parse_port_mapping("5433:5432") == (5433, 5432)


def check_evidence():
    assert verification_evidence == {
        "docker compose ps": "container status",
        "database connection": "credentials and network path",
        "SELECT PostGIS_Version()": "PostGIS extension availability",
    }


for name, check in [
    ("project_root", check_root),
    ("interpreter_context", check_interpreter),
    ("safe_url_parsing", check_url),
    ("port_mapping", check_ports),
    ("verification_evidence", check_evidence),
]:
    run_check(name, check)

# %%
# After writing responses, set written_points to 0, 1, or 2 and rerun this cell.
record_written_scores()
earned = sum(points for points, _ in scores.values())
possible = sum(maximum for _, maximum in scores.values())
percentage = 100 * earned / possible if possible else 0
status = "READY FOR MODULE 2" if earned >= 20 else "REVIEW MODULE 1 AND RETEST"
missed = [name for name, (points, maximum) in scores.items() if points < maximum]
assert possible == 25
print(f"Module 1 score: {earned}/{possible} ({percentage:.0f}%)")
print(status)
print("Review:", ", ".join(missed) if missed else "none")
