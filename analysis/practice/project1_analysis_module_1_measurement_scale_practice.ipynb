# %% [markdown]
# # Analysis Module A1 Practice: Measurement, Scale, and CRS
#
# Use controlled square polygons to verify area units before measuring Calgary communities.

# %%
import geopandas as gpd
from shapely.geometry import box

communities = gpd.GeoDataFrame(
    {"community_id": ["A", "B"]},
    geometry=[box(0, 0, 1000, 1000), box(1000, 0, 3000, 1000)],
    crs="EPSG:3347",
)

# %% [markdown]
# ## Predict First
#
# Predict each polygon's area in square metres and square kilometres before calculating it.

# %%
predicted_square_metres = []
predicted_square_kilometres = []

assert len(predicted_square_metres) == 2
assert len(predicted_square_kilometres) == 2

# %%
# TODO: calculate area_m2 and area_km2 without mutating communities.
measured = communities.copy()

assert list(measured["area_m2"]) == predicted_square_metres
assert list(measured["area_km2"]) == predicted_square_kilometres
assert "area_m2" not in communities.columns

# %% [markdown]
# ## Scale Reflection
#
# Write at least two reasons community polygons do not represent every resident's transit experience.

# %%
scale_limitations = []
assert len(scale_limitations) >= 2
assert all(str(item).strip() for item in scale_limitations)
