# %% [markdown]
# # Analysis Module A3 Practice: Normalization and Interpretation
#
# Compare raw counts and area-normalized density without confusing density with accessibility.

# %%
import pandas as pd

summary = pd.DataFrame({
    "community_id": ["A", "B", "C"],
    "stop_count": [10, 8, 2],
    "area_km2": [10.0, 2.0, 0.25],
})

# %%
predicted_count_order = []
predicted_density_order = []

assert set(predicted_count_order) == {"A", "B", "C"}
assert set(predicted_density_order) == {"A", "B", "C"}

# %%
# TODO: validate positive areas and calculate stops_per_km2.
result = summary.copy()

# TODO: derive descending community orders for both measures.
count_order = []
density_order = []

assert count_order == predicted_count_order
assert density_order == predicted_density_order
assert result["stops_per_km2"].ge(0).all()

# %% [markdown]
# ## Interpretation
#
# Write an observation, one possible explanation, one limitation, and one responsible next step. Do not claim accessibility or equity.

# %%
interpretation = {
    "observation": "",
    "possible_explanation": "",
    "limitation": "",
    "next_step": "",
}

assert all(len(value.split()) >= 8 for value in interpretation.values())
