# %% [markdown]
# # Analysis Module A1 Test: Measurement, Scale, and CRS
#
# Closed-note test. Total: 25 points. Recommended pass: 20 points.

# %% [markdown]
# ## Question 1: Area and Units (10 points)
#
# Create a projected GeoDataFrame containing a 2,000 m by 500 m rectangle. Calculate its area in square metres and square kilometres, preserving the original object.

# %%
import geopandas as gpd
from shapely.geometry import box

source = gpd.GeoDataFrame({"id": ["A"]}, geometry=[box(0, 0, 2000, 500)], crs="EPSG:3347")
result = source.copy()
# Complete the measurement.

assert result.loc[0, "area_m2"] == 1_000_000
assert result.loc[0, "area_km2"] == 1.0
assert "area_m2" not in source.columns

# %% [markdown]
# ## Question 2: CRS Reasoning (7 points)
#
# Explain why direct area from longitude/latitude is unsuitable and what must be recorded with a projected measurement.

# %%
answer_2 = ""
assert len(answer_2.split()) >= 45

# %% [markdown]
# ## Question 3: Scale and Boundaries (8 points)
#
# Explain MAUP, ecological fallacy, and one point-on-boundary concern for the community analysis.

# %%
answer_3 = ""
assert len(answer_3.split()) >= 65
score = 0
review_action = ""
assert 0 <= score <= 25
assert review_action.strip()
