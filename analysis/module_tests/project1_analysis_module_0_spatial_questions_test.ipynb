# %% [markdown]
# # Analysis Module A0 Test: Spatial Questions and Decision Value
#
# Closed-note test. Total: 25 points. Recommended pass: 20 points.

# %% [markdown]
# ## Question 1: Frame the Analysis (10 points)
#
# Identify a stakeholder and decision, then write a bounded spatial question using Project 1 communities and transit stops. State the unit of analysis, numerator, denominator, and spatial relationship.

# %%
answer_1 = {
    "stakeholder_and_decision": "",
    "question": "",
    "unit": "",
    "numerator": "",
    "denominator": "",
    "relationship": "",
}
assert all(value.strip() for value in answer_1.values())

# %% [markdown]
# ## Question 2: Scope Claims (8 points)
#
# Explain which claims current data can support and why population equity and service accessibility require additional evidence.

# %%
answer_2 = ""
assert len(answer_2.split()) >= 60

# %% [markdown]
# ## Question 3: Hypothesis and Value (7 points)
#
# State a falsifiable hypothesis about raw counts versus density and explain how the result could create bounded decision value.

# %%
answer_3 = ""
assert len(answer_3.split()) >= 40

# %% [markdown]
# ## Self-Score
#
# Award points only when each answer identifies both the method and its limitation. Record the score and one review action.

# %%
score = 0
review_action = ""
assert 0 <= score <= 25
assert review_action.strip()
