# %% [markdown]
# # Analysis Module A3 Test: Normalization and Interpretation
#
# Closed-note test. Total: 25 points. Record your answers without assigning points. After completing and saving the notebook, ask AI to grade the written and code work, verify the executable checks, and report evidence for each award or deduction. Recommended progression threshold after AI review: 20/25.

# %% [markdown]
# ## Question 1: Calculate and Compare (12 points)
#
# Validate areas, calculate stops per square kilometre, and compare descending raw-count and density orders.

# %%
import pandas as pd

source = pd.DataFrame({"id": ["A", "B", "C"], "stops": [12, 9, 3], "area_km2": [12.0, 3.0, 0.5]})
result = source.copy()
count_order = []
density_order = []
# Complete validation, calculation, and ordering.

assert list(result["stops_per_km2"]) == [1.0, 3.0, 6.0]
assert count_order == ["A", "B", "C"]
assert density_order == ["C", "B", "A"]

# %% [markdown]
# ## Question 2: Validation Plan (6 points)
#
# List at least six checks required before publication, including reconciliation and geographic inspection.

# %%
validation_checks = []
assert len(validation_checks) >= 6
assert all(str(check).strip() for check in validation_checks)

# %% [markdown]
# ## Question 3: Responsible Interpretation (7 points)
#
# Write an observation, limitation, and next step without claiming that density proves accessibility, equity, or service need.

# %%
answer_3 = ""
assert len(answer_3.split()) >= 70
print("Assessment responses recorded. Final score: awaiting AI review.")
