# %% [markdown]
# # Analysis Module A0 Practice: Spatial Questions and Decision Value
#
# Frame the first Project 1 analysis before selecting an operation. Write specific answers in your own words.

# %%
"""Frame the initial analysis contract."""

analysis_contract = {
    "stakeholder": "",
    "decision": "",
    "spatial_question": "",
    "unit_of_analysis": "",
    "numerator": "",
    "denominator": "",
    "spatial_relationship": "",
}

assert all(value.strip() for value in analysis_contract.values())

# %% [markdown]
# ## Prediction and Scope
#
# Predict how raw stop-count rankings may differ from area-normalized rankings. Then classify each claim as currently supported or requiring more data.

# %%
"""Record a prediction and classify the available evidence."""

PREDICTION = ""

claim_scope = {
    "mapped stops per square kilometre": "",
    "resident transit equity": "",
    "scheduled service frequency": "",
    "communities for deeper investigation": "",
}

assert PREDICTION.strip()
assert set(claim_scope.values()) <= {"supported", "more data required"}
assert all(claim_scope.values())

# %% [markdown]
# ## Reflection
#
# Explain why a technically correct map of stop density would still be insufficient to recommend a new route.

# %%
"""Explain why stop density alone cannot support a route decision."""

LIMITATION_EXPLANATION = ""
assert len(LIMITATION_EXPLANATION.split()) >= 30

# %% [markdown]
# ## AI Practice Review
#
# After completing the working copy, save it and ask Copilot:
#
# > Review my completed spatial-analysis practice notebook without assigning a progression grade. Preserve my original answers and code. Inspect my reasoning, assumptions, implementations, checks, errors, outputs, and interpretations. Cite evidence for demonstrated strengths and misconceptions, recommend the smallest useful exercises to retry, and ask targeted follow-up questions before giving complete corrected answers.
#
# After reviewing the feedback, preserve the completed notebook with `python scripts/save_attempt.py 0 --analysis`.
